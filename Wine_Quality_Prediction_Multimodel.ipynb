# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
wine_data = pd.read_csv(r"E:\DSML Datasets\winequality.csv")

# %%
wine_data.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine_data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
for key , value in wine_data.items() :
    if key != 'type' :
        wine_data[key] = wine_data[key].fillna(wine_data[key].mean())

# %%
wine_data.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
fig , ax = plt.subplots(ncols= 6 , nrows= 2 , figsize= (20,10))
index = 0
ax = ax.flatten()

for key , value in wine_data.items() :
    if key != 'type' :
       sns.boxplot(y= key , data= wine_data , ax= ax[index])
       index += 1  
plt.tight_layout(pad= 0.5 , w_pad= 0.7 , h_pad= 0.5)    
plt.show()

# %%
fig , ax = plt.subplots(ncols= 6 , nrows= 2 , figsize= (20,10))
index = 0
ax = ax.flatten()

for key , value in wine_data.items() :
    if key != 'type' :
       sns.distplot(value , ax= ax[index])
       index += 1  
plt.tight_layout(pad= 0.5 , w_pad= 0.7 , h_pad= 0.5)    
plt.show()

# %%
wine_data['free sulfur dioxide'] = np.log(1 + wine_data['free sulfur dioxide'])

# %%
sns.distplot(wine_data['free sulfur dioxide'])
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.countplot(x= wine_data['type'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.countplot(x= wine_data['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
corr = wine_data.drop(columns= 'type' , axis= 1).corr()
plt.figure(figsize= (12,6))
sns.heatmap(corr , annot= True , cmap= 'coolwarm')
# Out:
# <Axes: >

# %%
X = wine_data.drop(columns= ['type' , 'quality'] , axis= 1)
Y = wine_data['quality']

# %%
print(X.shape)
print(Y.value_counts())
# Out:
# (6497, 11)
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(k_neighbors = 4)
X , Y = oversample.fit_resample(X,Y)

# %%
from sklearn.model_selection import train_test_split , cross_val_score

def classify(model , X , Y) :
    X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size= 0.25 , random_state= 50)
    model.fit(X_train , Y_train)
    
    print("Accuracy Score :" , model.score(X_test , Y_test) * 100)
    
    cv_score = cross_val_score(model , X , Y , cv= 5)
    print("Cross Value Score :" , np.mean(cv_score) * 100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model , X , Y)
# Out:
# Accuracy Score : 35.663912955873464
# Cross Value Score : 33.13000234064727

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model , X , Y)
# Out:
# Accuracy Score : 80.79790449325004
# Cross Value Score : 74.97495507416173

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
classify(model , X , Y)
# Out:
# Accuracy Score : 88.53516018537175
# Cross Value Score : 82.32427923604824

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
classify(model , X , Y)
# Out:
# Accuracy Score : 89.28067700987306
# Cross Value Score : 83.34177573300636
